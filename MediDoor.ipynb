# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ```
# `# This is formatted as code`
# ```
#
# # Data Cleaning

# %% [markdown]
# This section involves extracting the required data from all the collected datasets and integrating them into a single dataset for further operations

# %% [markdown]
# ## Stroke_Dataset_2017_3_year_average

# %% [markdown]
# Cleaning the stroke dataset

# %%
stroke = s = pd.read_csv('/content/drive/MyDrive/MediDoor/Datasets/Stroke_Mortality_Data_Among_US_Adults__35___by_State_Territory_and_County___2016-2018.csv')

# %%
columns = stroke.columns

# %%
columns
# Out:
# Index(['Year', 'LocationAbbr', 'LocationDesc', 'GeographicLevel', 'DataSource',
#        'Class', 'Topic', 'Data_Value', 'Data_Value_Unit', 'Data_Value_Type',
#        'Data_Value_Footnote_Symbol', 'Data_Value_Footnote',
#        'StratificationCategory1', 'Stratification1', 'StratificationCategory2',
#        'Stratification2', 'TopicID', 'LocationID', 'Y_lat', 'X_lon'],
#       dtype='object')

# %%
stroke['Data_Value_Type'].unique()
# Out:
# array(['Age-adjusted, Spatially Smoothed, 3-year Average Rate',
#        'Age-adjusted, 3-year Average Rate'], dtype=object)

# %%
stroke = stroke[stroke['GeographicLevel'] == 'County']

# %%
extra_cols = (['DataSource','Class', 'Topic','Data_Value_Footnote','Data_Value_Unit','Data_Value_Footnote_Symbol','StratificationCategory1','StratificationCategory2','TopicID','GeographicLevel'])

# %%
stroke = stroke.drop(extra_cols,axis = 1)

# %%
stroke.rename(columns = {'Data_Value' : 'Data_Value(per 100,000 population)','LocationID' : 'FIPS Code'},inplace = True)

# %%
stroke.columns
# Out:
# Index(['Year', 'LocationAbbr', 'LocationDesc',
#        'Data_Value(per 100,000 population)', 'Data_Value_Type',
#        'Stratification1', 'Stratification2', 'FIPS Code', 'Y_lat', 'X_lon'],
#       dtype='object')

# %%
stroke_data = stroke[(stroke['Stratification1'] == 'Overall') & (stroke['Stratification2'] == 'Overall')]

# %%
stroke_data.drop(['Stratification1','Stratification2'],axis = 1,inplace = True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
stroke_data.rename(columns = {'Data_Value(per 100,000 population)' : 'Stroke_Data_Value_Overall(per 100,000 population)'},inplace = True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
stroke
# Out:
#        Year LocationAbbr       LocationDesc  \
# 0      2017           AK     Aleutians East
# 1      2017           AK     Aleutians West
# 2      2017           AK          Anchorage
# 3      2017           AK             Bethel
# 4      2017           AK        Bristol Bay
# ...     ...          ...                ...
# 59071  2017           WY  Sweetwater County
# 59072  2017           WY       Teton County
# 59073  2017           WY       Uinta County
# 59074  2017           WY    Washakie County
# 59075  2017           WY      Weston County
#
#        Data_Value(per 100,000 population)  \
# 0                                     2.0
# 1                                     0.0
# 2                                    67.2
# 3                                   104.6
# 4                                     NaN
# ...                                   ...
# 59071                                 NaN
# 59072                                 NaN
# 59073                                 NaN
# ...

# %%
for i in s['Stratification1'].unique():
  for j in s['Stratification2'].unique():
    df = stroke[(stroke['Stratification1'] == i) & (stroke['Stratification2'] == j)]
    print(df)
    stroke_data = stroke_data.merge(df[['Data_Value(per 100,000 population)','FIPS Code']],on = 'FIPS Code',how = 'outer')
    stroke_data.rename(columns = {'Data_Value(per 100,000 population)' : f'Stroke_Data_Value_{i}_{j}(per 100,000 population)','FIPS Code_x': 'FIPS Code'},inplace = True)
# Out:
#        Year LocationAbbr       LocationDesc  \
# 0      2017           AK     Aleutians East
# 1      2017           AK     Aleutians West
# 2      2017           AK          Anchorage
# 3      2017           AK             Bethel
# 4      2017           AK        Bristol Bay
# ...     ...          ...                ...
# 58680  2017           WY  Sweetwater County
# 58681  2017           WY       Teton County
# 58682  2017           WY       Uinta County
# 58683  2017           WY    Washakie County
# 58684  2017           WY      Weston County
#
#        Data_Value(per 100,000 population)  \
# 0                                     2.0
# 1                                     0.0
# 2                                    67.2
# 3                                   104.6
# 4                                     NaN
# ...                                   ...
# 58680                                61.7
# 58681                                60.2
# 58682                                62.9
# ...

# %%
stroke_data
# Out:
#       Year LocationAbbr       LocationDesc  \
# 0     2017           AK     Aleutians East
# 1     2017           AK     Aleutians West
# 2     2017           AK          Anchorage
# 3     2017           AK             Bethel
# 4     2017           AK        Bristol Bay
# ...    ...          ...                ...
# 3221  2017           WY  Sweetwater County
# 3222  2017           WY       Teton County
# 3223  2017           WY       Uinta County
# 3224  2017           WY    Washakie County
# 3225  2017           WY      Weston County
#
#       Stroke_Data_Value_Overall(per 100,000 population)  \
# 0                                                   2.0
# 1                                                   0.0
# 2                                                  67.2
# 3                                                 104.6
# 4                                                   NaN
# ...                                                 ...
# ...

# %%
stroke_data.to_csv('/content/drive/MyDrive/MediDoor/Cleaned Data/Stroke_Data_2017_Cleaned.csv')

# %% [markdown]
# ## Heart_Dataset_2015_3_year_average

# %% [markdown]
# Cleaning the heart dataset

# %%
heart = h = pd.read_csv('/content/drive/MyDrive/MediDoor/Datasets/Stroke_Mortality_Data_Among_US_Adults__35___by_State_Territory_and_County___2016-2018.csv')

# %%
columns = heart.columns

# %%
columns
# Out:
# Index(['Year', 'LocationAbbr', 'LocationDesc', 'GeographicLevel', 'DataSource',
#        'Class', 'Topic', 'Data_Value', 'Data_Value_Unit', 'Data_Value_Type',
#        'Data_Value_Footnote_Symbol', 'Data_Value_Footnote',
#        'StratificationCategory1', 'Stratification1', 'StratificationCategory2',
#        'Stratification2', 'TopicID', 'LocationID', 'Y_lat', 'X_lon'],
#       dtype='object')

# %%
heart['Data_Value_Type'].unique()
# Out:
# array(['Age-adjusted, Spatially Smoothed, 3-year Average Rate',
#        'Age-adjusted, 3-year Average Rate'], dtype=object)

# %%
heart = heart[heart['GeographicLevel'] == 'County']

# %%
extra_cols = (['DataSource','Class', 'Topic','Data_Value_Footnote','Data_Value_Unit','Data_Value_Footnote_Symbol','StratificationCategory1','StratificationCategory2','TopicID','GeographicLevel'])

# %%
heart = heart.drop(extra_cols,axis = 1)

# %%
heart.rename(columns = {'Data_Value' : 'Data_Value(per 100,000 population)','LocationID' : 'FIPS Code'},inplace = True)

# %%
heart.columns
# Out:
# Index(['Year', 'LocationAbbr', 'LocationDesc',
#        'Data_Value(per 100,000 population)', 'Data_Value_Type',
#        'Stratification1', 'Stratification2', 'FIPS Code', 'Y_lat', 'X_lon'],
#       dtype='object')

# %%
heart_data = heart[(heart['Stratification1'] == 'Overall') & (heart['Stratification2'] == 'Overall')]

# %%
heart_data.drop(['Stratification1','Stratification2'],axis = 1,inplace = True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
heart_data.rename(columns = {'Data_Value(per 100,000 population)' : 'Heart_Data_Value_Overall(per 100,000 population)'},inplace = True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
heart
# Out:
#        Year LocationAbbr       LocationDesc  \
# 0      2017           AK     Aleutians East
# 1      2017           AK     Aleutians West
# 2      2017           AK          Anchorage
# 3      2017           AK             Bethel
# 4      2017           AK        Bristol Bay
# ...     ...          ...                ...
# 59071  2017           WY  Sweetwater County
# 59072  2017           WY       Teton County
# 59073  2017           WY       Uinta County
# 59074  2017           WY    Washakie County
# 59075  2017           WY      Weston County
#
#        Data_Value(per 100,000 population)  \
# 0                                     2.0
# 1                                     0.0
# 2                                    67.2
# 3                                   104.6
# 4                                     NaN
# ...                                   ...
# 59071                                 NaN
# 59072                                 NaN
# 59073                                 NaN
# ...

# %%
for i in h['Stratification1'].unique():
  for j in h['Stratification2'].unique():
    df = heart[(heart['Stratification1'] == i) & (heart['Stratification2'] == j)]
    heart_data = heart_data.merge(df[['Data_Value(per 100,000 population)','FIPS Code']],on = 'FIPS Code',how = 'outer')
    heart_data.rename(columns = {'Data_Value(per 100,000 population)' : f'Heart_Data_Value_{i}_{j}(per 100,000 population)','FIPS Code_x': 'FIPS Code'},inplace = True)

# %%
heart_data
# Out:
#       Year LocationAbbr       LocationDesc  \
# 0     2017           AK     Aleutians East
# 1     2017           AK     Aleutians West
# 2     2017           AK          Anchorage
# 3     2017           AK             Bethel
# 4     2017           AK        Bristol Bay
# ...    ...          ...                ...
# 3221  2017           WY  Sweetwater County
# 3222  2017           WY       Teton County
# 3223  2017           WY       Uinta County
# 3224  2017           WY    Washakie County
# 3225  2017           WY      Weston County
#
#       Heart_Data_Value_Overall(per 100,000 population)  \
# 0                                                  2.0
# 1                                                  0.0
# 2                                                 67.2
# 3                                                104.6
# 4                                                  NaN
# ...                                                ...
# ...

# %%
heart_data.to_csv('/content/drive/MyDrive/MediDoor/Cleaned Data/Heart_Data_2015_Cleaned.csv')

# %% [markdown]
# ## Cardiovascular_Diseases_Dataset_10_year_average

# %% [markdown]
# Cleaning the cardiovascular diseases dataset

# %%
cardio = cv = pd.read_csv('/content/drive/MyDrive/MediDoor/Datasets/Rates_and_Trends_in_Hypertension-related_Cardiovascular_Disease_Mortality_Among_US_Adults__35___by_County__Age_Group__Race_Ethnicity__and_Sex___2000-2019.csv')

# %%
cardio.shape

# %%
columns = cardio.columns

# %%
columns

# %%
common_cols = []

# %%
cardio['Data_Value_Type'].unique()

# %%
for i in columns:  
  print(i,cardio[i].unique())
  if len(cardio[i].unique()) <= 1:
     common_cols.append(i)

# %%
common_cols

# %%
cardio.drop(common_cols,axis = 1,inplace = True)

# %%
cardio.drop(['Data_Value_Footnote_Symbol','Data_Value_Footnote'],axis = 1,inplace = True)

# %%
cardio.shape

# %%
cardio.rename(columns = {'Data_Value' : 'Data_Value(per 100,000 population)','LocationID' : 'FIPS Code'},inplace = True)

# %%
cardio.columns

# %%
cardio = cardio[cardio['Data_Value_Type'] == 'Age-Standardized, Spatiotemporally Smoothed Rate']

# %%
cardio['Data_Value_Unit'].unique()

# %%
cardio.drop(['Data_Value_Type','Data_Value_Unit'],axis = 1,inplace = True)

# %%
cardio.drop(['Confidence_limit_Low', 'Confidence_limit_High'],axis = 1,inplace = True)

# %%
cardio_data = cardio[(cardio['Year'] == '2000') & (cardio['Stratification1'] == 'Ages 35-64 years') & (cardio['Stratification2'] == 'Overall') & (cardio['Stratification3'] == 'Overall')]

# %%
cardio_data.rename(columns = {'Data_Value(per 100,000 population)' : 'Data_Value_35_overall_overall'},inplace = True)

# %%
cardio_data

# %%
cardio_data.drop(['Stratification1','Stratification2','Stratification3','Year'],axis = 1,inplace = True)

# %%
years = [str(i) for i in range(2000,2020)]

# %%
for year in years:
  for i in cv['Stratification1'].unique():
    for j in cv['Stratification2'].unique():
      for k in cv['Stratification3'].unique():
          df = cardio[(cardio['Year'] == year) & (cardio['Stratification1'] == i) & (cardio['Stratification2'] == j) & (cardio['Stratification3'] == k)]
          print(cardio_data.columns)
          cardio_data = cardio_data.merge(df[['Data_Value(per 100,000 population)','FIPS Code']],on = 'FIPS Code',how = 'outer')
          cardio_data.rename(columns = {'Data_Value(per 100,000 population)' : f'CV_Data_Value_{year}_{i}_{j}_{k}(per 100,000 population)','FIPS Code_x': 'FIPS Code'},inplace = True)

# %%
cardio_data

# %%
cardio_data.to_csv('/content/drive/MyDrive/MediDoor/Cleaned Data/CardioVascular_Hypertension_and_related_Data_2000_2019_Cleaned.csv',index = False)

# %% [markdown]
# ## Heart_Diseases_Stroke_Dataset_10_year_average

# %% [markdown]
# Cleaning the heart diseases dataset

# %%
cardio = cv = pd.read_csv('/content/drive/MyDrive/MediDoor/Datasets/Rates_and_Trends_in_Heart_Disease_and_Stroke_Mortality_Among_US_Adults__35___by_County__Age_Group__Race_Ethnicity__and_Sex___2000-2019.csv')

# %%
cardio.shape

# %%
columns = cardio.columns

# %%
columns

# %%
common_cols = []

# %%
year = cardio['Year'].unique()

# %%
year = list(year)

# %%
for i in year:
  if str(i) in year:
      year.remove(str(i))

# %%
year.sort()

# %%
year

# %%
diseases = list(cardio['Topic'].unique())

# %%
diseases

# %%
all_heart_diseases = cardio[cardio['Topic'] == 'All heart disease']
all_stroke = cardio[cardio['Topic'] == 'All stroke']
chd = cardio[cardio['Topic'] == 'Coronary heart disease (CHD)']
cvd = cardio[cardio['Topic'] == 'Cardiovascular disease (CVD)']
heart_failure = cardio[cardio['Topic'] == 'Heart failure']

# %%
datasets = [all_heart_diseases,all_stroke,chd,cvd,heart_failure]

# %%
all_heart_diseases.drop(['Stratification2'],axis = 1,inplace = True)
all_stroke.drop(['Stratification2'],axis = 1,inplace = True)
chd.drop(['Stratification2'],axis = 1,inplace = True)
cvd.drop(['Stratification2'],axis = 1,inplace = True)
heart_failure.drop(['Stratification2'],axis = 1,inplace = True)

# %%
all_heart_diseases = all_heart_diseases[all_heart_diseases['Stratification2'] == 'Overall']
all_stroke = all_stroke[all_stroke['Stratification2'] == 'Overall']
chd = chd[chd['Stratification2'] == 'Overall']
cvd = cvd[cvd['Stratification2'] == 'Overall']
heart_failure = heart_failure[heart_failure['Stratification2'] == 'Overall']

# %%
chd

# %%
for i in cardio.columns:  
  print(i,cardio[i].unique())
  if len(cardio[i].unique()) <= 1:
     common_cols.append(i)

# %%
common_cols

# %%
cardio.drop(common_cols,axis = 1,inplace = True)

# %%
cardio.drop(['Data_Value_Footnote_Symbol','Data_Value_Footnote'],axis = 1,inplace = True)

# %%
cardio.shape

# %%
cardio.rename(columns = {'Data_Value' : 'Data_Value(per 100,000 population)','LocationID' : 'FIPS Code'},inplace = True)

# %%
cardio.columns

# %%
cardio = cardio[cardio['Data_Value_Type'] == 'Age-Standardized, Spatiotemporally Smoothed Rate']

# %%
cardio['Data_Value_Unit'].unique()

# %%
cardio.drop(['Data_Value_Type','Data_Value_Unit'],axis = 1,inplace = True)

# %%
cardio.drop(['Confidence_limit_Low', 'Confidence_limit_High'],axis = 1,inplace = True)

# %%
cardio_data = cardio[(cardio['Year'] == '2000') & (cardio['Stratification1'] == 'Ages 35-64 years') & (cardio['Stratification3'] == 'Overall')]

# %%
all_heart_diseases_data  = all_heart_diseases[((all_heart_diseases['Year'] == '2000') | (all_heart_diseases['Year'] == 2000)) & (all_heart_diseases['Stratification1'] == 'Ages 35-64 years') & (all_heart_diseases['Stratification3'] == 'Overall')]
all_stroke_data  = all_stroke[((all_stroke['Year'] == '2000') | (all_stroke['Year'] == 2000)) & (all_stroke['Stratification1'] == 'Ages 35-64 years') & (all_stroke['Stratification3'] == 'Overall')]
chd_data  = chd[((chd['Year'] == '2000') |(chd['Year'] == 2000)) & (chd['Stratification1'] == 'Ages 35-64 years') & (chd['Stratification3'] == 'Overall')]
cvd_data  = cvd[((cvd['Year'] == '2000') | (cvd['Year'] == 2000)) & (cvd['Stratification1'] == 'Ages 35-64 years') & (cvd['Stratification3'] == 'Overall')]
heart_failure_data  = heart_failure[((heart_failure['Year'] == '2000')| (heart_failure['Year'] == 2000)) & (heart_failure['Stratification1'] == 'Ages 35-64 years') & (heart_failure['Stratification3'] == 'Overall')]

# %%
all_heart_diseases_data
# Out:
#          Year LocationAbbr LocationDesc              Topic  \
# 122      2000           AL      Autauga  All heart disease
# 1808     2000           AL      Baldwin  All heart disease
# 3494     2000           AL      Barbour  All heart disease
# 5179     2000           AL         Bibb  All heart disease
# 6847     2000           AL       Blount  All heart disease
# ...       ...          ...          ...                ...
# 5260222  2000           WY   Sweetwater  All heart disease
# 5261906  2000           WY        Teton  All heart disease
# 5263577  2000           WY        Uinta  All heart disease
# 5265261  2000           WY     Washakie  All heart disease
# 5266941  2000           WY       Weston  All heart disease
#
#          Data_Value_35_overall_overall_2000   Stratification1 Stratification3  \
# 122                                   160.1  Ages 35-64 years         Overall
# 1808                                  121.4  Ages 35-64 years         Overall
# ...

# %%
all_heart_diseases_data.rename(columns = {'Data_Value(per 100,000 population)' : 'Data_Value_35_overall_overall_2000'},inplace = True)
all_stroke_data.rename(columns = {'Data_Value(per 100,000 population)' : 'Data_Value_35_overall_overall_2000'},inplace = True)
chd_data.rename(columns = {'Data_Value(per 100,000 population)' : 'Data_Value_35_overall_overall_2000'},inplace = True)
cvd_data.rename(columns = {'Data_Value(per 100,000 population)' : 'Data_Value_35_overall_overall_2000'},inplace = True)
heart_failure_data.rename(columns = {'Data_Value(per 100,000 population)' : 'Data_Value_35_overall_overall_2000'},inplace = True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
cardio_data

# %%
cardio_data.drop(['Stratification1','Stratification2','Stratification3','Year'],axis = 1,inplace = True)

# %%
for y in year:
  for i in cvd['Stratification1'].unique():
      for k in heart_failure['Stratification3'].unique():
          df = heart_failure[((heart_failure['Year'] == y) | (heart_failure['Year'] == str(y))) & (heart_failure['Stratification1'] == i) & (heart_failure['Stratification3'] == k)]
          print(all_heart_diseases_data.columns)
          all_heart_diseases_data = all_heart_diseases_data.merge(df[['Data_Value(per 100,000 population)','FIPS Code']],on = 'FIPS Code',how = 'outer')
          all_heart_diseases_data.rename(columns = {'Data_Value(per 100,000 population)' : f'Heart_Failure_Data_Value_{y}_{i}_{k}(per 100,000 population)','FIPS Code_x': 'FIPS Code'},inplace = True)

# %%
all_heart_diseases_data

# %%
all_heart_diseases_data.to_csv('/content/drive/MyDrive/MediDoor/Cleaned Data/Heart_Diseases_Stroke_and_related_Data_2000_2019_Cleaned.csv',index = False)

# %% [markdown]
# ## CKD_2005_2019

# %%
ckd = pd.read_excel('/content/drive/MyDrive/MediDoor/Datasets/Prevalence_of_CKD_by_US_State_and_County_by_County_2019.xlsm','Data For Entire Data Source')

# %%
ckd.sort_values(by = ['Year','State','County'],inplace = True)

# %%
ckd_data = ckd[0:3124]

# %%
ckd_data.rename(columns = {'Main Value':'CKD_Value_2005'},inplace = True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
ckd_data
# Out:
#        CKD_Value_2005      County    State  Year
# 0                9.95     AUTAUGA  Alabama  2005
# 15               8.49     BALDWIN  Alabama  2005
# 30              15.86     BARBOUR  Alabama  2005
# 45               9.64        BIBB  Alabama  2005
# 60              14.11      BLOUNT  Alabama  2005
# ...               ...         ...      ...   ...
# 46781           11.41  SWEETWATER  Wyoming  2005
# 46796            8.86       TETON  Wyoming  2005
# 46811            4.48       UINTA  Wyoming  2005
# 46826            5.17    WASHAKIE  Wyoming  2005
# 46841            6.25      WESTON  Wyoming  2005
#
# [3124 rows x 4 columns]

# %%
for i in range(2006,2020):
  df = ckd[ckd['Year'] == i]
  print(ckd_data)
  ckd_data = ckd_data.merge(df[['Main Value','County','State']],on = ['County','State'],how = 'left')
  ckd_data.rename(columns = {'Main Value' : f'CKD_Value_{i}'},inplace = True)

# %%
ckd_data.to_csv('/content/drive/MyDrive/MediDoor/Cleaned Data/CKD Data')

# %% [markdown]
# # Data Preprocessing

# %%
data = pd.read_csv('/content/drive/MyDrive/MediDoor/Cleaned Data/Heart_Diseases_Stroke_and_related_Data_1999_2019_Cleaned - Heart_Diseases_Stroke_and_related_Data_2000_2019_Cleaned.csv')

# %%
data

# %%
extra = []
for i in data.columns:
  if 'men' in i.lower() or 'women' in i.lower():
    extra.append(i)

# %%
len(extra)

# %%
data.drop(extra,axis = 1,inplace = True)

# %%
columns = data.columns

# %%
ahd_columns = [i for i in columns if 'All_Heart_Diseases' in i]
stroke_columns = [i for i in columns if 'All_Stroke' in i]
chd_columns = [i for i in columns if 'Coronary' in i]
cvd_columns = [i for i in columns if 'Cardiovascular' in i]
hf_columns = [i for i in columns if 'Heart_Failure' in i]

# %%
ahd_35 = [i for i in ahd_columns if '35' in i]
ahd_64 = [i for i in ahd_columns if '64+' in i]
as_35 = [i for i in stroke_columns if '35' in i]
as_64 = [i for i in stroke_columns if '64+' in i]
chd_35 = [i for i in chd_columns if '35' in i]
chd_64 = [i for i in chd_columns if '64+' in i]
cvd_35 = [i for i in cvd_columns if '35' in i]
cvd_64 = [i for i in cvd_columns if '64+' in i]
hf_35 = [i for i in hf_columns if '35' in i]
hf_64 = [i for i in hf_columns if '64+' in i]

# %%
len(ahd_35)

# %%
data['All_Heart_Diseases_Trend_35-64'] = 0
data['All_Heart_Diseases_Trend_64+'] = 0
data['All_Stroke_Trend_35-64'] = 0
data['All_Stroke_Trend_64+'] = 0
data['Coronary_Heart_Diseases_Trend_35-64'] = 0
data['Coronary_Heart_Diseases_Trend_64+'] = 0
data['Cardiovascular_Diseases_Trend_35-64'] = 0
data['Cardiovascular_Diseases_Trend_64+'] = 0
data['Heart_Failures_Trend_35-64'] = 0
data['Heart_Failures_Trend_64+'] = 0

# %%
ahd_35

# %%
data

# %%
for j in range(3136):
#  curr = data[ahd_35[0]].values[j]
  count = 0
  for i in range(len(hf_64)-1):
 #   if count > max_count:
      #  max_count = count
    if data[hf_64[i+1]].values[j] < data[hf_64[i]].values[j]:
       # curr = data[ahd_64[i]].values[j]
        count = 0
    elif data[hf_64[i+1]].values[j] > data[hf_64[i]].values[j]:
        count += 1
  data['Heart_Failures_Trend_64+'].values[j] = count
  #print(data['All_Heart_Diseases_Trend_64+'])

# %%
data

# %%
data.to_csv('/content/drive/MyDrive/MediDoor/Cleaned Data/Final Dataset1.csv',index = False)

# %%
df = pd.read_excel('/content/drive/MyDrive/MediDoor/Datasets/US Counties.xlsx',dtype={"FIPS CODE":"str"})

# %%
df['FIPS CODE'].fillna(0,inplace = True)

# %%
df['FIPS CODE'] = df['FIPS CODE'].astype(int)

# %%
df

# %%
data =  pd.read_csv('/content/drive/MyDrive/MediDoor/Cleaned Data/Final Dataset1.csv')

# %%
columns = list(data.columns)[-10:]

# %%
columns

# %%
for i in columns:
  data[f'{i}'] += 1

# %%
data

# %%
data.rename(columns = {'FIPS Code':'FIPS CODE'},inplace = True)

# %%
data = data.merge(df[['2010 POPULATION','LAND AREA (Sqare Miles)','FIPS CODE']],on = 'FIPS CODE',how = 'left')

# %% [markdown]
# ## Hospitals

# %%
data['Hospitals'] = 0

# %%
data

# %%
hos_address = pd.read_csv('/content/drive/MyDrive/MediDoor/Datasets/Hospital_Additional_Addresses.csv',encoding = 'latin1')

# %%
hos_address

# %%
for i in hos_address:  
  hos_address['CITY'] = hos_address['CITY'].str.title()

# %%
county_city = pd.read_csv('/content/drive/MyDrive/MediDoor/Datasets/uscities.csv')

# %%
county_city

# %%
for i in range(25169):
  for row in range(30410):
    try:
      if (hos_address['CITY'].values[i] == county_city['city'].values[row]) and (hos_address['STATE'].values[i] == county_city['state_id'].values[row]):
        fips = county_city['county_fips'].values[row]
        index = int(data[data['FIPS CODE'] == fips].index[0])
        data['Number of Hospitals'].values[index] += 1        
        break
    except IndexError:
      pass

# %%
data

# %%
index = int(data[data['FIPS CODE'] == 1001].index[0])
data['Number of Hospitals'].values[index] += 1

# %%
temp = data[data['Number of Hospitals'] == 0]

# %%
temp = temp.sort_values(by = '2010 POPULATION',ascending = False)

# %%
temp[:20]
# Out:
#       FIPS CODE State        County  \
# 1852      36061    NY      New York
# 1591      29510    MO     St. Louis
# 2341      45063    SC     Lexington
# 2820      51013    VA     Arlington
# 62         1125    AL    Tuscaloosa
# 368       12109    FL     St. Johns
# 2899      51179    VA      Stafford
# 2309      44009    RI    Washington
# 2898      51177    VA  Spotsylvania
# 2707      48381    TX       Randall
# 2352      45085    SC        Sumter
# 1204      24037    MD    St. Mary's
# 3060      55039    WI   Fond du Lac
# 1876      36109    NY      Tompkins
# 1193      24015    MD         Cecil
# 487       13217    GA        Newton
# 1208      24045    MD      Wicomico
# 2890      51161    VA       Roanoke
# 1559      29165    MO        Platte
# 1487      29021    MO      Buchanan
#
#       All_Heart_Diseases_Data_Value_1999_Ages 35-64 years_Overall(per 100,000 population)  \
# 1852                                              118.7
# ...

# %%
data.to_csv('/content/drive/MyDrive/MediDoor/Cleaned Data/PreFinal Dataset2.csv')

# %%
data = pd.read_csv('/content/drive/MyDrive/MediDoor/Cleaned Data/PreFinal Dataset2.csv')

# %%
data['Average Hospital Approximity'] = data['LAND AREA (Sqare Miles)']/data['Number of Hospitals']

# %%
data['Number of People(per 1 hospital)'] = data['2010 POPULATION']/data['Number of Hospitals']

# %%
data.to_csv('/content/drive/MyDrive/MediDoor/Cleaned Data/PreFinal Dataset3.csv')

# %%
data = pd.read_csv('/content/drive/MyDrive/MediDoor/Cleaned Data/PreFinal Dataset3.csv')

# %%
ckd_data['County'] = ckd_data['County'].str.title()

# %%
ckd_data = pd.read_csv('/content/drive/MyDrive/MediDoor/Cleaned Data/CKD Data')

# %%
ckd_data.drop(columns = ['Unnamed: 0'],axis = 1)

# %%
ckd_data.to_csv('/content/drive/MyDrive/MediDoor/Cleaned Data/CKD Data.csv',index = False)

# %%
ckd_data = pd.read_csv('/content/drive/MyDrive/MediDoor/Cleaned Data/CKD Data.csv')

# %%
ckd_data

# %%
data = data.merge(ckd_data,on = ['County'],how = 'inner')

# %%
ckd_data['County'] = ckd_data['County'].str.title()

# %%
ckd_data

# %%
df = pd.read_excel('/content/drive/MyDrive/MediDoor/Datasets/US Counties.xlsx')

# %%
df['FIPS CODE'] = df['FIPS CODE'].astype(int)

# %%
df['FIPS CODE'] = df['FIPS CODE'].fillna(0)

# %%
df['COUNTY NAME'] = df['COUNTY NAME'].str.rstrip('County')

# %%
df['COUNTY NAME'] = df['COUNTY NAME'].str.rstrip('Parish')

# %%
df['COUNTY NAME'] = df['COUNTY NAME'].str.rstrip('Census Area')

# %%
df['COUNTY NAME'] = df['COUNTY NAME'].str.rstrip('Municipality')

# %%
df.rename(columns = {'STATE/TERRITORY NAME' : 'State','COUNTY NAME':'County'},inplace = True)

# %%
df['County'] = df['County'].str.title()

# %%
ckd_data['County']=ckd_data['County'].str.strip()

# %%
df2 = ckd_data.merge(df,how = 'left',on = ['County','State'])

# %%
data = data.merge(df1,on = 'FIPS CODE',how = 'left')

# %%
data
# Out:
#       Unnamed: 0_x  Unnamed: 0.1  FIPS CODE State_x    County_x  \
# 0                0             0       1001      AL     Autauga
# 1                1             1       1003      AL     Baldwin
# 2                2             2       1005      AL     Barbour
# 3                3             3       1007      AL        Bibb
# 4                4             4       1009      AL      Blount
# ...            ...           ...        ...     ...         ...
# 3131          3131          3131      56037      WY  Sweetwater
# 3132          3132          3132      56039      WY       Teton
# 3133          3133          3133      56041      WY       Uinta
# 3134          3134          3134      56043      WY    Washakie
# 3135          3135          3135      56045      WY      Weston
#
#       All_Heart_Diseases_Data_Value_1999_Ages 35-64 years_Overall(per 100,000 population)  \
# 0                                                 155.7
# ...

# %%
data.columns
# Out:
# Index(['FIPS CODE', 'State_x', 'County_x',
#        'All_Heart_Diseases_Data_Value_1999_Ages 35-64 years_Overall(per 100,000 population)',
#        'All_Heart_Diseases_Data_Value_1999_Ages 65 years and older_Overall(per 100,000 population)',
#        'All_Heart_Diseases_Data_Value_2000_Ages 35-64 years_Overall(per 100,000 population)',
#        'All_Heart_Diseases_Data_Value_2000_Ages 65 years and older_Overall(per 100,000 population)',
#        'All_Heart_Diseases_Data_Value_2001_Ages 35-64 years_Overall(per 100,000 population)',
#        'All_Heart_Diseases_Data_Value_2001_Ages 65 years and older_Overall(per 100,000 population)',
#        'All_Heart_Diseases_Data_Value_2002_Ages 35-64 years_Overall(per 100,000 population)',
#        ...
#        'CKD_Value_2013', 'CKD_Value_2014', 'CKD_Value_2015', 'CKD_Value_2016',
#        'CKD_Value_2017', 'CKD_Value_2018', 'CKD_Value_2019', 'STATE FIPS',
#        'COUNTY FIPS', 'Population Density '],
#       dtype='object', length=248)

# %%
data
# Out:
#       FIPS CODE State_x    County_x  \
# 0          1001      AL     Autauga
# 1          1003      AL     Baldwin
# 2          1005      AL     Barbour
# 3          1007      AL        Bibb
# 4          1009      AL      Blount
# ...         ...     ...         ...
# 3131      56037      WY  Sweetwater
# 3132      56039      WY       Teton
# 3133      56041      WY       Uinta
# 3134      56043      WY    Washakie
# 3135      56045      WY      Weston
#
#       All_Heart_Diseases_Data_Value_1999_Ages 35-64 years_Overall(per 100,000 population)  \
# 0                                                 155.7
# 1                                                 130.3
# 2                                                 209.4
# 3                                                 168.8
# 4                                                 150.3
# ...                                                 ...
# 3131                                              107.9
# ...

# %%
data.drop(columns = ['Unnamed: 0_x', 'Unnamed: 0.1','2010 POPULATION_y', '2015 POPULATION',
       'LAND AREA (Sqare Miles)_y', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
       'Unnamed: 11', 'State_y', 'County_y',],axis = 1,inplace = True)

# %%
data.rename(columns = {'State_x' : 'State' , 'County_x' : 'County'})
# Out:
#       FIPS CODE State      County  \
# 0          1001    AL     Autauga
# 1          1003    AL     Baldwin
# 2          1005    AL     Barbour
# 3          1007    AL        Bibb
# 4          1009    AL      Blount
# ...         ...   ...         ...
# 3131      56037    WY  Sweetwater
# 3132      56039    WY       Teton
# 3133      56041    WY       Uinta
# 3134      56043    WY    Washakie
# 3135      56045    WY      Weston
#
#       All_Heart_Diseases_Data_Value_1999_Ages 35-64 years_Overall(per 100,000 population)  \
# 0                                                 155.7
# 1                                                 130.3
# 2                                                 209.4
# 3                                                 168.8
# 4                                                 150.3
# ...                                                 ...
# 3131                                              107.9
# 3132                                               52.4
# ...

# %% [markdown]
# # Data Inference

# %%
data
# Out:
#       FIPS CODE State_x    County_x  \
# 0          1001      AL     Autauga
# 1          1003      AL     Baldwin
# 2          1005      AL     Barbour
# 3          1007      AL        Bibb
# 4          1009      AL      Blount
# ...         ...     ...         ...
# 3131      56037      WY  Sweetwater
# 3132      56039      WY       Teton
# 3133      56041      WY       Uinta
# 3134      56043      WY    Washakie
# 3135      56045      WY      Weston
#
#       All_Heart_Diseases_Data_Value_1999_Ages 35-64 years_Overall(per 100,000 population)  \
# 0                                                 155.7
# 1                                                 130.3
# 2                                                 209.4
# 3                                                 168.8
# 4                                                 150.3
# ...                                                 ...
# 3131                                              107.9
# ...

# %%
diseases = ['All_Heart_Diseases','All_Stroke','Coronary_Heart_Diseases','Cardiovascular_Diseases','Heart_Failure']

# %%
for disease in diseases:
  m = f'{disease}_Average_Mortality'
  mp = f'{disease}_Average_Mortality(in %)'
  data[m] = 0
  data[mp] = 0
  for year in range(1999,2020):
    col1 = f'{disease}_Data_Value_{year}_Ages 35-64 years_Overall(per 100,000 population)'
    col2 = f'{disease}_Data_Value_{year}_Ages 65 years and older_Overall(per 100,000 population)'
    data[m] += data[col1]
    data[m] += data[col2]
  data[m] = (data[m]/20)
  data[m] = (data[m]*data['2010 POPULATION_x'])/100000
  data[mp] = (data[m]/data['2010 POPULATION_x'])*100

# %%
disease = 'CKD'
m = f'{disease}_Average_Mortality'
mp = f'{disease}_Average_Mortality(in %)'
data[m] = 0
data[mp] = 0
for year in range(2005,2020):
    col1 = f'{disease}_Value_{year}'
    data[m] += data[col1]
data[m] = (data[m]/20)
data[m] = (data[m]*data['2010 POPULATION_x'])/100000
data[mp] = (data[m]/data['2010 POPULATION_x'])*100

# %%
data
# Out:
#       FIPS CODE State_x    County_x  \
# 0          1001      AL     Autauga
# 1          1003      AL     Baldwin
# 2          1005      AL     Barbour
# 3          1007      AL        Bibb
# 4          1009      AL      Blount
# ...         ...     ...         ...
# 3131      56037      WY  Sweetwater
# 3132      56039      WY       Teton
# 3133      56041      WY       Uinta
# 3134      56043      WY    Washakie
# 3135      56045      WY      Weston
#
#       All_Heart_Diseases_Data_Value_1999_Ages 35-64 years_Overall(per 100,000 population)  \
# 0                                                 155.7
# 1                                                 130.3
# 2                                                 209.4
# 3                                                 168.8
# 4                                                 150.3
# ...                                                 ...
# 3131                                              107.9
# ...

# %%
data.to_csv('/content/drive/MyDrive/MediDoor/Cleaned Data/Final Prefinal Dataset.csv')

# %%
data = pd.read_csv('/content/drive/MyDrive/MediDoor/Cleaned Data/Final Prefinal Dataset.csv')

# %%
data

# %%
diseases = ['All_Heart_Diseases','All_Stroke','Coronary_Heart_Diseases','Cardiovascular_Diseases','Heart_Failure']

# %%
for i in diseases:
  s = f'{i}_Trend'  
  s1 = f'{i}_Trend_35-64'
  s2 = f'{i}_Trend_64+'
  data[s] = data[[s1,s2]].max(axis = 1)

# %%
data
# Out:
#       Unnamed: 0  FIPS CODE State_x    County_x  \
# 0              0       1001      AL     Autauga
# 1              1       1003      AL     Baldwin
# 2              2       1005      AL     Barbour
# 3              3       1007      AL        Bibb
# 4              4       1009      AL      Blount
# ...          ...        ...     ...         ...
# 3131        3131      56037      WY  Sweetwater
# 3132        3132      56039      WY       Teton
# 3133        3133      56041      WY       Uinta
# 3134        3134      56043      WY    Washakie
# 3135        3135      56045      WY      Weston
#
#       All_Heart_Diseases_Data_Value_1999_Ages 35-64 years_Overall(per 100,000 population)  \
# 0                                                 155.7
# 1                                                 130.3
# 2                                                 209.4
# 3                                                 168.8
# 4                                                 150.3
# ...

# %%
data.rename(columns = {'Heart_Failures_Trend' : 'Heart_Failure_Trend'},inplace = True)

# %%
for i in diseases:
  impact = f'{i}_Impact(in %)'
  m = f'{i}_Average_Mortality(in %)'
  trend = f'{i}_Trend'
  data[impact] = data[m]*data[trend]

# %%
data
# Out:
#       Unnamed: 0  FIPS CODE State_x    County_x  \
# 0              0       1001      AL     Autauga
# 1              1       1003      AL     Baldwin
# 2              2       1005      AL     Barbour
# 3              3       1007      AL        Bibb
# 4              4       1009      AL      Blount
# ...          ...        ...     ...         ...
# 3131        3131      56037      WY  Sweetwater
# 3132        3132      56039      WY       Teton
# 3133        3133      56041      WY       Uinta
# 3134        3134      56043      WY    Washakie
# 3135        3135      56045      WY      Weston
#
#       All_Heart_Diseases_Data_Value_1999_Ages 35-64 years_Overall(per 100,000 population)  \
# 0                                                 155.7
# 1                                                 130.3
# 2                                                 209.4
# 3                                                 168.8
# 4                                                 150.3
# ...

# %%
data['CKD_Trend'] = 0

# %%
for j in range(3136):
#  curr = data[ahd_35[0]].values[j]
  count = 0
  for i in range(2005,2019):
 #   if count > max_count:
      #  max_count = count
      curr = f'CKD_Value_{i}'
      next = f'CKD_Value_{i}'
      if data[curr].values[j] < data[next].values[j]:
       # curr = data[ahd_64[i]].values[j]
        count = 0
      elif data[curr].values[j] > data[next].values[j]:
        count += 1
  data['CKD_Trend'].values[j] = count
  #print(data['All_Heart_Diseases_Trend_64+'])

# %%
data['CKD_Trend'] += 1

# %%
data['CKD_Impact(in %)'] = data['CKD_Average_Mortality(in %)']*data['CKD_Trend']

# %%
data.to_csv('/content/drive/MyDrive/MediDoor/Cleaned Data/Final Super Dataset.csv')

# %%
extra = []
for i in data.columns:
  if '64' in i:
    extra.append(i)

# %%
extra
# Out:
# ['All_Heart_Diseases_Trend_35-64',
#  'All_Heart_Diseases_Trend_64+',
#  'All_Stroke_Trend_35-64',
#  'All_Stroke_Trend_64+',
#  'Coronary_Heart_Diseases_Trend_35-64',
#  'Coronary_Heart_Diseases_Trend_64+',
#  'Cardiovascular_Diseases_Trend_35-64',
#  'Cardiovascular_Diseases_Trend_64+',
#  'Heart_Failures_Trend_35-64',
#  'Heart_Failures_Trend_64+']

# %%
data.drop(columns = ['Unnamed: 0'],axis = 1,inplace = True)

# %%
data.rename(columns = {'State_x' : 'State','County_x' : 'County','2010 POPULATION_x' : '2010 POPULATION','LAND AREA (Sqare Miles)_x' : 'LAND AREA (Sqare Miles)'},inplace = True)

# %%
data.columns
# Out:
# Index(['FIPS CODE', 'State', 'County', '2010 POPULATION',
#        'LAND AREA (Sqare Miles)', 'Number of Hospitals',
#        'Average Hospital Approximity', 'Number of People(per 1 hospital)',
#        'STATE FIPS', 'COUNTY FIPS', 'Population Density ',
#        'All_Heart_Diseases_Average_Mortality', 'All_Stroke_Average_Mortality',
#        'Coronary_Heart_Disease_Average_Mortality',
#        'Coronary_Heart_Diseases_Average_Mortality',
#        'Cardiovascular_Diseases_Average_Mortality',
#        'Heart_Failure_Average_Mortality',
#        'All_Heart_Diseases_Average_Mortality(in %)',
#        'All_Stroke_Average_Mortality(in %)',
#        'Coronary_Heart_Diseases_Average_Mortality(in %)',
#        'Cardiovascular_Diseases_Average_Mortality(in %)',
#        'Heart_Failure_Average_Mortality(in %)', 'CKD_Average_Mortality',
#        'CKD_Average_Mortality(in %)', 'All_Heart_Diseases_Trend',
#        'All_Stroke_Trend', 'Coronary_Heart_Diseases_Trend',
# ...

# %%
columns = ['FIPS CODE', 'State', 'County', '2010 POPULATION',
       'LAND AREA (Sqare Miles)', 'Number of Hospitals',
       'Average Hospital Approximity', 'Number of People(per 1 hospital)',
       'STATE FIPS', 'COUNTY FIPS', 'Population Density ',
       'All_Heart_Diseases_Average_Mortality', 'All_Stroke_Average_Mortality',
       'Coronary_Heart_Diseases_Average_Mortality',
       'Cardiovascular_Diseases_Average_Mortality',
       'Heart_Failure_Average_Mortality',
       'CKD_Average_Mortality',
       'All_Heart_Diseases_Average_Mortality(in %)',
       'All_Stroke_Average_Mortality(in %)',
       'Coronary_Heart_Diseases_Average_Mortality(in %)',
       'Cardiovascular_Diseases_Average_Mortality(in %)',
       'Heart_Failure_Average_Mortality(in %)',
       'CKD_Average_Mortality(in %)', 'All_Heart_Diseases_Trend',
       'All_Stroke_Trend', 'Coronary_Heart_Diseases_Trend',
       'Cardiovascular_Diseases_Trend', 'Heart_Failure_Trend','CKD_Trend',
       'All_Heart_Diseases_Impact(in %)', 'All_Stroke_Impact(in %)',
       'Coronary_Heart_Diseases_Impact(in %)',
       'Cardiovascular_Diseases_Impact(in %)', 'Heart_Failure_Impact(in %)',
        'CKD_Impact(in %)']

# %%
data = data[columns]

# %%
data.to_csv('/content/drive/MyDrive/MediDoor/Cleaned Data/Final Compact Dataset.csv')

# %%
data['Prominent Disease'] = (data[['All_Heart_Diseases_Impact(in %)','All_Stroke_Impact(in %)','Coronary_Heart_Diseases_Impact(in %)','Cardiovascular_Diseases_Impact(in %)','Heart_Failure_Impact(in %)','Chronic_Kidney_Disease_Impact(in %)']].idxmax(axis=1))

# %%
data['Prominent Disease'] = data['Prominent Disease'].str.rstrip('_Impact(in %)')

# %%
data = pd.read_csv('/content/drive/MyDrive/MediDoor/Cleaned Data/Final Executable Dataset.csv')

# %%
data =  data.dropna(subset = ['Prominent Disease'])

# %%
data

# %%
data.rename(columns = {'CKD_Average_Mortality' : 'Chronic_Kidney_Disease_Average_Mortality','CKD_Average_Mortality(in %)' : 'Chronic_Kidney_Disease_Average_Mortality(in %)','CKD_Trend' : 'Chronic_Kidney_Disease_Trend','CKD_Impact(in %)' : 'Chronic_Kidney_Disease_Impact(in %)'},inplace = True)

# %%
data.to_csv('/content/drive/MyDrive/MediDoor/Cleaned Data/Final Executable Dataset.csv',index=False)

# %%
import numpy as np
import plotly.offline as offline
from sklearn.preprocessing import MinMaxScaler
import plotly
import plotly.figure_factory as ff
from urllib.request import urlopen
import plotly.io as plio
import json
with urlopen('https://raw.githubusercontent.com/plotly/datasets/master/geojson-counties-fips.json') as response:
    counties = json.load(response)
import pandas as pd
scaler = MinMaxScaler((0,100))


import plotly.express as px
df =  pd.read_csv('/content/drive/MyDrive/MediDoor/Cleaned Data/Final Executable Dataset.csv')
df.rename
df['FIPS CODE']=df['FIPS CODE'].apply(lambda x: '{0:0>5}'.format(x) )
 # df['risk'] = scaler.fit_transform(np.array(df['risk']).reshape(-1,1))
fig = px.choropleth(df,geojson = counties,locations='FIPS CODE', color='Prominent Disease',
                           color_continuous_scale="ylorrd",
                           custom_data = [df['Prominent Disease'],
df['FIPS CODE'], df['County']],
                           scope="usa")
             
hovertemp = '<i style="color:red;">Prominent Disease: %{customdata[0]}</i><br>'
hovertemp += '<i>FIPS Code:</i> %{customdata[1]}<br>'
hovertemp += '<i>County:</i> %{customdata[2]}<br>'
# I set my own hover template
fig.update_traces(hovertemplate=hovertemp) 
plio.write_html(fig, file='/content/drive/MyDrive/MediDoor/Data Visualisation/Final Map.html', auto_open=True)

#fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
#plotly.io.to_image(fig, format='jpeg',
 #                  scale=None, width=None, height=None)
#fig.write_image("/content/drive/MyDrive/Colab Notebooks/images/month1.jpeg")
